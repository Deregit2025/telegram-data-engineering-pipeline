# %%
import pandas as pd
import sqlalchemy
import matplotlib.pyplot as plt
import seaborn as sns

# DB connection (Postgres)
DB_URI = "postgresql+psycopg2://postgres:YOUR_PASSWORD@localhost:5432/telegram_dw"
engine = sqlalchemy.create_engine(DB_URI)

# %%
import pandas as pd
import sqlalchemy
import matplotlib.pyplot as plt
import seaborn as sns

# DB connection (Postgres)
DB_URI = "postgresql+psycopg2://postgres:YOUR_PASSWORD@localhost:5432/telegram_dw"
engine = sqlalchemy.create_engine(DB_URI)

# %%
# Load messages fact table
fct_messages = pd.read_sql("SELECT * FROM analytics_analytics.fct_messages LIMIT 10000", engine)
fct_messages.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\derej\Desktop\Kifya\ELT\.venv\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\derej\Desktop\Kifya\ELT\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3309, in Engine.raw_connection(self)
#    3288 """Return a "raw" DBAPI connection from the connection pool.
#    3289
#    3290 The returned object is a proxied version of the DBAPI
#    (...)   3307
#    3308 """
# -> 3309 return self.pool.connect()
#
# File c:\Users\derej\Desktop\Kifya\ELT\.venv\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
# ...

# %%
from graphviz import Digraph

dot = Digraph(comment='Telegram Star Schema')
dot.node('F', 'fct_messages')
dot.node('C', 'dim_channels')
dot.node('D', 'dim_dates')
dot.edges([('F', 'C'), ('F', 'D')])
dot.render('notebooks/star_schema', format='png', cleanup=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\derej\Desktop\Kifya\ELT\.venv\Lib\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# ...

# %%
posts_per_day = fct_messages.groupby('date_key').size()
plt.figure(figsize=(12,6))
posts_per_day.plot()
plt.title("Total Posts Over Time")
plt.xlabel("Date Key")
plt.ylabel("Number of Posts")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 posts_per_day = fct_messages.groupby('date_key').size()
#       2 plt.figure(figsize=(12,6))
#       3 posts_per_day.plot()
#
# NameError: name 'fct_messages' is not defined

# %%
posts_per_channel = fct_messages.groupby('channel_key').size().reset_index(name='total_posts')
posts_per_channel = posts_per_channel.merge(dim_channels, on='channel_key')
sns.barplot(x='channel_name', y='total_posts', data=posts_per_channel)
plt.xticks(rotation=45)
plt.title("Total Posts by Channel")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 posts_per_channel = fct_messages.groupby('channel_key').size().reset_index(name='total_posts')
#       2 posts_per_channel = posts_per_channel.merge(dim_channels, on='channel_key')
#       3 sns.barplot(x='channel_name', y='total_posts', data=posts_per_channel)
#
# NameError: name 'fct_messages' is not defined

# %%
fct_image = pd.read_sql("SELECT * FROM analytics_analytics.fct_image_detections", engine)
sns.countplot(x='image_category', data=fct_image)
plt.title("Distribution of Image Categories")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\derej\Desktop\Kifya\ELT\.venv\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\derej\Desktop\Kifya\ELT\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3309, in Engine.raw_connection(self)
#    3288 """Return a "raw" DBAPI connection from the connection pool.
#    3289
#    3290 The returned object is a proxied version of the DBAPI
#    (...)   3307
#    3308 """
# -> 3309 return self.pool.connect()
#
# File c:\Users\derej\Desktop\Kifya\ELT\.venv\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
# ...
